# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import data and set up path

# %%
df = pd.read_pickle(r'C:\Users\christina.savva\Documents\CF Achievement 4 - Instacart Basket Analysis\02 Data\Prepared Data\orders_products_agg.pkl')

# %%
path = r'C:\Users\christina.savva\Documents\CF Achievement 4 - Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\christina.savva\\Documents\\CF Achievement 4 - Instacart Basket Analysis'

# %%
df_ords_prods_merge = df

# %%
df_ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %% [markdown]
# # 4.8.2 In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # 4.8.3 Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %%
#  The results are showing the full list of department IDs as opposed to only a selection from the first 1m rows in the exercise. The lowest mean has increased to 15.21 (from 11.29) and the highest has increased to 22.9 (from 19.31).

# %% [markdown]
# # 4.8.4 Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#  creating the new column to classify max_order groupings

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#  assignung the max_order groupings

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %% [markdown]
# # 4.8.5 The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
#  running summary statistics for the customer loyalty type (using loyalty_flag) and respective prices

# %%
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
#  Result: Loyal customers purchase products with the lowest avg. price point of $10.40, followed by regular customers at $12.50, which are just 5% below new customers at avg. product prices of $13.29.

# %% [markdown]
# # 4.8.6 The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:

# %% [markdown]
# # - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”

# %% [markdown]
# # - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
#  creating the new column to classify spend groupings

# %%
df_ords_prods_merge['spend_group'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.max)

# %%
#  assignung the spend_group groupings

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['spend_group'] >= 10, 'spend_flag'] = 'High spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['spend_group'] < 10, 'spend_flag'] = 'Low spender'

# %%
df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %% [markdown]
# # 4.8.7 In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:

# %% [markdown]
# # - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”

# %% [markdown]
# # - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”

# %% [markdown]
# # - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
#  creating the new column to classify order frequency groupings

# %%
df_ords_prods_merge['order_frequency'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.max)

# %%
#  assignung the order_frequency groupings

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_frequency'] <= 20) & (df_ords_prods_merge['order_frequency'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['order_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# ...

# %%
#  checking median of frequency groupings

# %%
df_ords_prods_merge.groupby('frequency_flag')['days_since_prior_order'].median()
# Out:
# frequency_flag
# Frequent customer        4.0
# Non-frequent customer    9.0
# Regular customer         6.0
# Name: days_since_prior_order, dtype: float64

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_4.8_task.pkl'))
