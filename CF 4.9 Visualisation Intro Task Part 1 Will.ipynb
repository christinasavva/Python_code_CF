# %% [markdown]
# # Import analysis libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import data and set up path

# %%
df = pd.read_csv(r'C:\Users\willm\Instacart Basket Analysis\02 Data\Original Data\ccustomers.csv', index_col = False)

# %%
path = r'C:\Users\willm\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\willm\\Instacart Basket Analysis'

# %% [markdown]
# # 4.9.4 Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df.rename(columns = {'First Name' : 'first_name'}, inplace = True)  #  correcting 'First Name' column name

# %%
df.rename(columns = {'Surnam' : 'surname'}, inplace = True)  #  correcting 'Surnam' column name

# %%
df.rename(columns = {'Gender' : 'gender'}, inplace = True)  #  changing first letter to lower case

# %%
df.rename(columns = {'STATE' : 'state'}, inplace = True)  #  changing UPPER case 'STATE' column to lower case

# %%
df.rename(columns = {'Age' : 'age'}, inplace = True)  #  changing first letter to lower case

# %%
df.rename(columns = {'n_dependants' : 'children'}, inplace = True)  #  changing 'n_dependants' column to make is slimmer

# %%
df.rename(columns = {'fam_status' : 'family_status'}, inplace = True)  #  changing 'fam_status' column to more detailed name

# %%
df.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    children family_status  income
# 0         3       married  165665
# 1         0        single   59285
# 2         2       married   99568
# 3         0        single   42049
# 4         1       married   40374

# %% [markdown]
# # 4.9.5 Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
df.info()  #  checking data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  int64
#  1   first_name     194950 non-null  object
#  2   surname        206209 non-null  object
#  3   gender         206209 non-null  object
#  4   state          206209 non-null  object
#  5   age            206209 non-null  int64
#  6   date_joined    206209 non-null  object
#  7   children       206209 non-null  int64
#  8   family_status  206209 non-null  object
#  9   income         206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
df['user_id'] = df['user_id'].astype('str')  #  changing data type of column 'user_id' from integer to string

# %%
df['age'] = df['age'].astype('int8')  #  changing data type of column 'age' to int8 to save memory

# %%
df['children'] = df['children'].astype('int8')  #  changing data type of column 'children' to int8 to save memory

# %%
df['income'] = df['income'].astype('int32')  #  changing data type of column 'children' to int8 to save memory

# %%
df.info()  #  validating data type changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  object
#  1   first_name     194950 non-null  object
#  2   surname        206209 non-null  object
#  3   gender         206209 non-null  object
#  4   state          206209 non-null  object
#  5   age            206209 non-null  int8
#  6   date_joined    206209 non-null  object
#  7   children       206209 non-null  int8
#  8   family_status  206209 non-null  object
#  9   income         206209 non-null  int32
# dtypes: int32(1), int8(2), object(7)
# memory usage: 12.2+ MB

# %%
df.isnull().sum()  #  checking for missing values
# Out:
# user_id              0
# first_name       11259
# surname              0
# gender               0
# state                0
# age                  0
# date_joined          0
# children             0
# family_status        0
# income               0
# dtype: int64

# %%
df_nan = df[df['first_name'].isnull() == True]  #  creating new dataframe to review missing variables

# %%
df_nan.head(20)
# Out:
#     user_id first_name     surname  gender           state  age date_joined  \
# 53    76659        NaN     Gilbert    Male        Colorado   26    1/1/2017
# 73    13738        NaN       Frost  Female       Louisiana   39    1/1/2017
# 82    89996        NaN      Dawson  Female          Oregon   52    1/1/2017
# 99    96166        NaN     Oconnor    Male        Oklahoma   51    1/1/2017
# 105   29778        NaN      Dawson  Female            Utah   63    1/1/2017
# 128    8562        NaN     Oconnor    Male            Utah   46    1/1/2017
# 140  149267        NaN  Hutchinson    Male  South Carolina   20    1/1/2017
# 149   82632        NaN         Orr    Male          Hawaii   61    1/1/2017
# 155  172331        NaN  Williamson  Female          Alaska   27    1/1/2017
# 236  182963        NaN   Nicholson  Female      New Mexico   58    1/2/2017
# 241   49727        NaN       Moran    Male          Alaska   53    1/2/2017
# ...

# %%
df['first_name'].fillna('Not provided', inplace=True)  #  replace the missing 'first_name' values 'Not provided'

# %%
df.isnull().sum()  #  validating that there are no more missing values
# Out:
# user_id          0
# first_name       0
# surname          0
# gender           0
# state            0
# age              0
# date_joined      0
# children         0
# family_status    0
# income           0
# dtype: int64

# %%
df_dups = df[df.duplicated()]  #  checking dataframe for duplicate entries

# %%
df_dups  #  no duplicate entries
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, state, age, date_joined, children, family_status, income]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  object
#  1   first_name     206209 non-null  object
#  2   surname        206209 non-null  object
#  3   gender         206209 non-null  object
#  4   state          206209 non-null  object
#  5   age            206209 non-null  int8
#  6   date_joined    206209 non-null  object
#  7   children       206209 non-null  int8
#  8   family_status  206209 non-null  object
#  9   income         206209 non-null  int32
# dtypes: int32(1), int8(2), object(7)
# memory usage: 12.2+ MB

# %%
df.describe()  #  checking summary statistics
# Out:
#                  age       children         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %% [markdown]
# # 4.9.6 Combine your customer data with the rest of your prepared Instacart data. Tip: Make sure the key columns are of the same data type!

# %%
df_customers = df  #  renaming customers DF

# %%
df_customers.head()
# Out:
#   user_id first_name   surname  gender       state  age date_joined  children  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017         3
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017         0
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017         2
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017         0
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017         1
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %%
df_ords_prods = pd.read_pickle(r'C:\Users\willm\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_4.8_task.pkl')  #  import ords_prods file

# %%
df_ords_prods.head()
# Out:
#   order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329        1    prior             1                   2
# 1  2398795        1    prior             2                   3
# 2   473747        1    prior             3                   3
# 3  2254736        1    prior             4                   4
# 4   431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order      first_order  product_id  \
# 0                  8                     NaN      First Order         196
# 1                  7                    15.0  Repeat Customer         196
# 2                 12                    21.0  Repeat Customer         196
# 3                  7                    29.0  Repeat Customer         196
# 4                 15                    28.0  Repeat Customer         196
#
#    add_to_cart_order  ...    price_range_loc     busiest_day    busiest_days  \
# ...

# %%
df_ords_prods.info()  #  key column user_id set as integer which I am going to change to string in order to match with df_customers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 26 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   first_order             object
#  8   product_id              int64
#  9   add_to_cart_order       int64
#  10  reordered               int64
#  11  product_name            object
#  12  aisle_id                int64
#  13  department_id           int64
#  14  prices                  float64
#  15  _merge                  category
#  16  price_range_loc         object
#  17  busiest_day             object
#  18  busiest_days            object
#  19  busiest_period_of_day   object
#  20  max_order               int64
# ...

# %%
df_ords_prods_2 = df_ords_prods.drop(columns = ['_merge'])  #  removing _merge column

# %%
df_ords_prods_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   first_order             object
#  8   product_id              int64
#  9   add_to_cart_order       int64
#  10  reordered               int64
#  11  product_name            object
#  12  aisle_id                int64
#  13  department_id           int64
#  14  prices                  float64
#  15  price_range_loc         object
#  16  busiest_day             object
#  17  busiest_days            object
#  18  busiest_period_of_day   object
#  19  max_order               int64
#  20  loyalty_flag            object
# ...

# %%
# chaning data type for identifying key

# %%
df_ords_prods_2['user_id'] = df_ords_prods_2['user_id'].astype('str')

# %%
df_ords_prods_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   first_order             object
#  8   product_id              int64
#  9   add_to_cart_order       int64
#  10  reordered               int64
#  11  product_name            object
#  12  aisle_id                int64
#  13  department_id           int64
#  14  prices                  float64
#  15  price_range_loc         object
#  16  busiest_day             object
#  17  busiest_days            object
#  18  busiest_period_of_day   object
#  19  max_order               int64
#  20  loyalty_flag            object
# ...

# %%
df_ords_prods_3 = df_ords_prods_2.drop(columns = ['add_to_cart_order'])  #  remove add_to_cart_order column

# %%
df_ords_prods_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   first_order             object
#  8   product_id              int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  price_range_loc         object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  spend_group             float64
# ...

# %%
#  chaning data types reduce memory

# %%
df_ords_prods_3['order_number'] = df_ords_prods_3['order_number'].astype('int8')

# %%
df_ords_prods_3['orders_day_of_week'] = df_ords_prods_3['orders_day_of_week'].astype('int8')

# %%
df_ords_prods_3['order_hour_of_day'] = df_ords_prods_3['order_hour_of_day'].astype('int8')

# %%
df_ords_prods_3['product_id'] = df_ords_prods_3['product_id'].astype('int16')

# %%
df_ords_prods_3['reordered'] = df_ords_prods_3['reordered'].astype('int8')

# %%
df_ords_prods_3['aisle_id'] = df_ords_prods_3['aisle_id'].astype('int8')

# %%
df_ords_prods_3['department_id'] = df_ords_prods_3['department_id'].astype('int8')

# %%
df_ords_prods_3['max_order'] = df_ords_prods_3['max_order'].astype('int8')

# %%
df_ords_prods_3.head()
# Out:
#   order_id user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329       1    prior             1                   2
# 1  2398795       1    prior             2                   3
# 2   473747       1    prior             3                   3
# 3  2254736       1    prior             4                   4
# 4   431534       1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order      first_order  product_id  \
# 0                  8                     NaN      First Order         196
# 1                  7                    15.0  Repeat Customer         196
# 2                 12                    21.0  Repeat Customer         196
# 3                  7                    29.0  Repeat Customer         196
# 4                 15                    28.0  Repeat Customer         196
#
#    reordered  ...    price_range_loc     busiest_day    busiest_days  \
# 0          0  ...  Mid-range product  Regularly busy  Regularly busy
# ...

# %%
df = df_ords_prods_3.merge(df_customers, on = ['user_id'], indicator = True)

# %%
#  creating a sample of the ords_prods dataframe as it is too big for my machine to process it
#  creating a list of holding True/False values to the test np.random.rant() <= 0.7

# %%
np.random.seed(4)
dev = np.random.rand(len(df_ords_prods_3)) <= 0.6

# %%
# Store 70% of the sample in the DF big and 30% in the DF small

# %%
big = df_ords_prods_3[dev]
small = df_ords_prods_3[~dev]

# %%
df.to_pickle(os.path.join(path, '02 Data','Prepared Data', '49_output.pkl'))
